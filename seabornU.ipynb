# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
from sklearn import datasets

# %%
sns.set(style = 'darkgrid')

# %%
a = sns.load_dataset('tips')
a
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # RELPLOT

# %%
#sns.relplot(x= a.iloc[:,0],y = a.iloc[:,1], data = a)
sns.relplot(x= 'total_bill',y = 'tip', data = a)

# %%
sns.relplot(x= 'total_bill',y = 'tip', data = a, hue = 'smoker')

# %%
sns.relplot(x= 'total_bill',y = 'tip', hue = 'smoker',data = a, style = 'time')

# %%
sns.relplot(x= 'total_bill',y = 'tip',hue = 'size',data = a)

# %%
sns.relplot(x= 'total_bill',y = 'tip', size = 'size',data = a)

# %%
sns.relplot(x= 'total_bill',y = 'tip',size = 'size',data = a, palette = 'ch:r =-.5,l = 0.95')

# %%
sns.relplot(x= 'total_bill',y = 'tip',style = 'size',data = a)

# %%
sns.relplot(x= 'total_bill',y = 'tip',size = 'size',sizes = (20,100),data = a)

# %% [markdown]
# # LINEPLOT

# %%
df = pd.DataFrame(dict(time = np.arange(0,500), values = np.random.randn(500).cumsum()))

# %%
df
# Out:
#      time     values
# 0       0   2.588530
# 1       1   3.536818
# 2       2   3.132062
# 3       3   4.317130
# 4       4   4.795460
# ..    ...        ...
# 495   495  22.366785
# 496   496  21.261918
# 497   497  22.416022
# 498   498  22.728323
# 499   499  22.698245
#
# [500 rows x 2 columns]

# %%
sns.lineplot(x = 'time', y = 'values', data = df)

# %%
df1 = pd.DataFrame(np.random.randn(500,2).cumsum(axis = 0), columns = ['time','values'])

# %%
df1
# Out:
#           time    values
# 0     2.298955 -0.245515
# 1     1.055585  1.053146
# 2     1.122546  1.444735
# 3     2.241316  0.556165
# 4     2.301218  2.815313
# ..         ...       ...
# 495  10.717915 -5.856860
# 496  11.219019 -3.624691
# 497  10.157950 -3.200737
# 498  10.246195 -3.924997
# 499  10.220898 -4.814415
#
# [500 rows x 2 columns]

# %%
sns.lineplot(x = 'time', y = 'values', data = df1, sort = True)

# %%
sns.lineplot(x = 'time', y = 'values', data = df1, sort = False)

# %%
frm = sns.load_dataset('fmri')
frm
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(x = 'timepoint', y = 'signal', data = frm)

# %%
sns.lineplot(x = 'timepoint', y = 'signal', data = frm, ci = False)

# %%
sns.lineplot(x = 'timepoint', y = 'signal', data = frm, ci = 'sd')

# %%
sns.lineplot(x = 'timepoint', y = 'signal', data = frm, estimator = None)

# %%
#plt.plot(frm.iloc[:,1],frm.iloc[:,4])
sns.lineplot(x = 'timepoint', y = 'signal', hue = 'event',data = frm)

# %%
sns.lineplot(x = 'timepoint', y = 'signal',hue = 'region' , style = 'event',data = frm)

# %%
sns.lineplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event',data = frm, marker = True)

# %%
dot = sns.load_dataset('dots').query('align == "dots"')
dot
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 389  dots     T2   680        3.2    37.806267
# 390  dots     T2   700        0.0    43.464959
# 391  dots     T2   700        3.2    38.994559
# 392  dots     T2   720        0.0    41.987121
# 393  dots     T2   720        3.2    41.716057
#
# [394 rows x 5 columns]

# %%
sns.lineplot(x = 'time', y = 'firing_rate', data = dot, hue ='coherence', style = 'choice')
sns.relplot(x = 'time', y = 'firing_rate', data = dot, hue ='coherence', style = 'choice', kind = 'line')

# %%
palette = sns.cubehelix_palette(light=.7, n_colors=6)
sns.relplot(x='time',y ='firing_rate',hue='coherence', style = 'choice', data = dot, palette = palette, kind = 'line')

# %%
df2 = pd.DataFrame(dict(time = pd.date_range('2019-06-02', periods= 500), values = np.random.randn(500).cumsum()))
df2.head()
# Out:
#         time    values
# 0 2019-06-02 -0.061558
# 1 2019-06-03 -0.026519
# 2 2019-06-04 -0.828625
# 3 2019-06-05 -1.968527
# 4 2019-06-06 -2.939899

# %%
b= sns.relplot(x ='time' , y = 'values', data = df2, kind = 'line')
b.fig.autofmt_xdate()
# Out:
# C:\Users\lenovo\Anaconda3\envs\joshua2\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
sns.relplot(x='total_bill', y = 'tip', hue = 'smoker',col = 'time', data = a)

# %%
sns.relplot(x='total_bill', y = 'tip', hue = 'smoker',col = 'size', data = a)

# %%
sns.relplot(x="timepoint", y="signal", hue="subject",
            col="region", row="event", height=3,
            kind="line", estimator=None, data=frm)

# %% [markdown]
# # CATPLOT

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.catplot(x= 'day', y= 'total_bill', data = a)

# %%
a
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(y= 'smoker', x= 'total_bill', data = a)

# %%
sns.catplot(x= 'day', y= 'total_bill', data = a,  jitter = False)

# %%
sns.catplot(x= 'day', y= 'total_bill', data = a, kind = 'swarm', hue = 'size', order = ['Sun','Thur','Fri','Sat'])

# %%
sns.catplot(x= 'smoker', y= 'tip', data = a, kind = 'swarm', hue = 'size', order = ['No','Yes'])

# %%
sns.catplot(x= 'day', y= 'total_bill', data = a, kind = 'box', hue = 'sex')

# %%
sns.catplot(x= 'day', y= 'total_bill', data = a, kind = 'box', hue = 'sex', dodge = False)

# %%
diamonds = sns.load_dataset('diamonds')
diamonds = diamonds.sort_values('color')
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
# 7817    1.00  Very Good     D     SI2   63.5   59.0   4295  6.35  6.32  4.02
# 7816    1.00       Good     D     SI2   57.8   58.0   4295  6.61  6.55  3.80
# 7815    1.00  Very Good     D     SI2   61.5   63.0   4295  6.32  6.27  3.87
# 7809    0.56      Ideal     D      IF   61.9   57.0   4293  5.28  5.31  3.28
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 4861    1.00    Premium     J     SI1   60.8   58.0   3712  6.39  6.44  3.90
# 18421   1.52      Ideal     J     SI1   61.9   57.0   7491  7.37  7.33  4.55
# 18423   1.50  Very Good     J     VS2   62.6   58.0   7492  7.25  7.29  4.55
# 42108   0.65      Ideal     J     SI1   61.4   55.0   1276  5.58  5.62  3.44
# 14123   1.30      Ideal     J     SI1   61.5   55.0   5728  7.03  7.06  4.33
#
# [53940 rows x 10 columns]

# %%
sns.catplot(x= 'color', y = 'price',data = diamonds, kind ='boxen')

# %%
g = sns.catplot(x= 'day', y= 'total_bill', data = a, kind = 'violin', split= True)
sns.catplot(x= 'day', y= 'total_bill', data = a,color = 'k', kind = 'swarm', ax = g.ax)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x= 'sex',y = 'survived',hue = 'class', kind = 'bar', data =titanic)

# %%
sns.catplot(x= 'deck',kind = 'count', data =titanic, palette = 'ch:r = 0.55')

# %%
x  =np.random.randn(100)
sns.distplot(x)

# %%
sns.distplot(x, rug = True, kde = True, hist =False)

# %%
sns.distplot(x,kde = False, bins = 20)

# %%
sns.kdeplot(x, shade =True, vertical = False, bw = 1)

# %%
sns.kdeplot(x, shade =True, vertical = True)

# %%
c = a.iloc[:,0]
d = a.iloc[:,1]

# %%
sns.jointplot(x= c, y = d)

# %%
sns.axes_style('white')
sns.jointplot(x= c, y = d, kind ='resid')

# %%
sns.axes_style('white')
w =sns.jointplot(x= c, y = d, kind ='kde', color = 'g')

# %%
sns.axes_style('white')
sns.jointplot(x= c, y = d, kind ='reg')

# %%
sns.axes_style('white')
sns.jointplot(x= c, y = d, kind ='hex')

# %%
iris  = datasets.load_iris()
iris = pd.DataFrame(data =iris.data, columns = iris.feature_names)
sns.pairplot(iris)

# %%
r = sns.PairGrid(iris)
r.map_diag(sns.kdeplot)
r.map_offdiag(sns.kdeplot, n_levels = 5)

# %%
a.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(x = 'total_bill', y = 'tip', data = a)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = a)

# %%
sns.lmplot(x = 'size', y = 'tip', data = a, x_jitter= 0.05)

# %%
sns.lmplot(x = 'size', y = 'tip', data = a, x_estimator = np.median)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = a, hue = 'sex', markers = ['o','+'], col = 'time', row = 'smoker')

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = a, col='day',col_wrap = 2, height = 3)

# %% [markdown]
# # figure, axes styling
# # color palette

# %%
def sinplot(y = 1):
    x = np.linspace(0,14,100)
    for k in range(1,7):
        plt.plot(x, np.sin(x+k*0.5)*(7-k)*y)

# %%
sinplot(2)

# %%
sns.set_style('white')
sns.set_context('talk', font_scale = 2)
sinplot()

# %%
c_palette = sns.color_palette()
sns.palplot(c_palette)

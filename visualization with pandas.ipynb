# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from numpy.random import randn, randint, sample, uniform

# %%
df = pd.DataFrame(randn(1000), index =pd.date_range('2018-03-31', periods =1000), columns = ['values'])

# %%
df['values'] = df['values'].cumsum()
df.head()
# Out:
#               values
# 2018-03-31  0.020823
# 2018-04-01 -0.201394
# 2018-04-02 -1.063118
# 2018-04-03 -1.173335
# 2018-04-04 -2.289885

# %%
df.plot(figsize = (10,8))

# %%
iris = sns.load_dataset('iris')

# %%
iris.plot(figsize = (10,8), title = 'iris')
plt.xlabel('x -axis')
plt.ylabel('y -axis')
# Out:
# Text(0, 0.5, 'y -axis')

# %%
iris.drop(['species'], axis =1).iloc[0].plot(kind = 'bar')

# %%
titanic = sns.load_dataset('titanic')

# %%
df = pd.DataFrame(randn(10,4), columns = ['a','b','c','d'])

# %%
df.plot.bar()

# %%
df.plot.bar(stacked = True)

# %%
df.plot.barh(stacked = True)

# %%
iris.plot.hist(bins  = 10)

# %%
iris.plot.hist(stacked = True)

# %%
iris.plot.hist(stacked = True, orientation = 'horizontal')

# %%
df.diff().hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000025953F17F08>,
# ...
#       dtype=object)

# %%
df2 = iris.drop(['species'], axis =1)

# %%
df.diff().hist(figsize = (8,8), color = 'g')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002595406AC08>,
# ...
#       dtype=object)

# %%
df2.plot.box(figsize = (8,6))

# %%
df2.plot.box(figsize = (8,6), vert = False)

# %%
df2.plot.area()

# %%
df2.plot.area(stacked = False)

# %%
df2.plot.scatter(x ='sepal_length', y  = 'petal_length', c = 'sepal_width')

# %%
ay = df2.plot.scatter(x = 'sepal_length', y = 'petal_length')
df2.plot.scatter(x = 'sepal_width', y = 'petal_width', color = 'g', ax = ay)

# %%
iris.plot.hexbin(x = 'sepal_length', y = 'petal_length', C = 'sepal_width', gridsize = 25)

# %%
df3 = df2.head(4)
df3.plot.pie(subplots = True, figsize = (30,30))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002595C287EC8>,
# ...
#       dtype=object)

# %%
df3.T.plot.pie(subplots = True, figsize = (55,55))
df3.T
# Out:
#                 0    1    2    3
# sepal_length  5.1  4.9  4.7  4.6
# sepal_width   3.5  3.0  3.2  3.1
# petal_length  1.4  1.4  1.3  1.5
# petal_width   0.2  0.2  0.2  0.2

# %%
df3.T.plot.pie(subplots = True, figsize = (55,55), autopct = '%.2f', fontsize = 45)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002595CED05C8>,
# ...
#       dtype=object)

# %%
series = pd.Series([0.23]*4)
series.plot.pie()

# %%
sns.pairplot(iris)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(iris, figsize = (10,10))
plt.show()
